# %% [raw]
# ---
# description: A JAX wrapper around ceviche to make interoperability easier. In the
#   future it might make sense to update ceviche itself to use JAX internally.
# output-file: index.html
# title: javiche
#
# ---

# %%
#| hide
from javiche.core import *

# %% [markdown]
# This file will become your README and also the index of your documentation.

# %% [markdown]
# ## Install

# %% [markdown]
# ```sh
# pip install javiche
# ```

# %% [markdown]
# ## How to use

# %% [markdown]
# Fill me in please! Don't forget code examples:

# %%
1+1
# Out:
# 2
